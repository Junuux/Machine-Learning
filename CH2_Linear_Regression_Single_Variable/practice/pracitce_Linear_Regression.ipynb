# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### 라이브러리

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### 데이터 불러오기

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df.tail()
# Out:
#     year  per capita income (US$)
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %% [markdown]
# ### 데이터 분포

# %%
# %matplotlib inline
plt.scatter(df.year, df['per capita income (US$)'], marker = '.')
plt.xlabel('year')
plt.ylabel('per capita income')
# Out:
# Text(0, 0.5, 'per capita income')

# %% [markdown]
# ### 예측하고자 하는 기간 데이터프레임화

# %%
df_add = pd.DataFrame({'year':[2017,2018,2019,2020],
                       'per capita income (US$)':[0,0,0,0]},
                      index=[47,48,49,50])
df_add
# Out:
#     year  per capita income (US$)
# 47  2017                        0
# 48  2018                        0
# 49  2019                        0
# 50  2020                        0

# %% [markdown]
# ### LinearRegression

# %%
reg = LinearRegression()
reg.fit(df[['year']], df['per capita income (US$)'])

pred = reg.predict(df_add[['year']])
df_add['per capita income (US$)'] = pred
df_add
# Out:
#     year  per capita income (US$)
# 47  2017             38803.298869
# 48  2018             39631.763944
# 49  2019             40460.229019
# 50  2020             41288.694094

# %% [markdown]
# ### 데이터프레임 합치기

# %%
df = pd.concat([df, df_add])
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %% [markdown]
# ### 2016~2020 예측치 확인

# %%
# %matplotlib inline
plt.scatter(df.year, df['per capita income (US$)'], marker = '.')
plt.plot(df.year, reg.predict(df[['year']]), color='red')
plt.xlabel('year')
plt.ylabel('per capita income')
# Out:
# Text(0, 0.5, 'per capita income')
